# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from lse import LSE
#       3 client = LSE(api_key="lse_live_0ff120bc30cec1d93a6588f9892e3a72")
#       5 # daily candles for BTC since Jan 1, then the last 200 hourly candles fo|r AAPL
#
# ModuleNotFoundError: No module named 'lse'

# %%
hourt
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/21 06:26:43 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
spark.range(5).writeTo("nessie.default.test_table").createOrReplace()
spark.sql("SELECT * FROM nessie.default.test_table").show()
# Out:
# 26/06/21 06:26:53 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# +---+
# | id|
# +---+
# |  0|
# |  1|
# |  2|
# |  3|
# |  4|
# +---+
